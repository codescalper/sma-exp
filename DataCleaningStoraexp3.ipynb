# %% [markdown]
# <a href="https://colab.research.google.com/github/codescalper/sma-exp/blob/main/DataCleaningStoraexp3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from googleapiclient.discovery import build
import pandas as pd

# %%
api_key = 'AIzaSyBT3GkJ8WUvdum1PGd3aFAXHc3eXgs19Sg'
youtube = build ('youtube', 'v3', developerKey = api_key)
channel_id = [
    "UCeVMnSShP_Iviwkknt83cww",
    "UC606MUq45P3zFLa4VGKbxsg",
    "UCBwmMxybNva6P_5VmxjzwqA",
    "UCw5hEVOTfz_AfzsNFWyNlNg",
    "UC1NF71EwP41VdjAU1iXdLkw",
]

# %%
def getStats(youtube, channel_id):
  all_data = []
  request = youtube.channels().list(
    part = 'snippet,contentDetails, statistics',
    id = ','.join(channel_id))
  response = request.execute()
  for i in range(len(response['items'])):
    data = dict(
        channel_name = response['items'][i]['snippet']['title'],
        Subcribers = response['items'][i]['statistics']['subscriberCount'],
        Views = response['items'][i]['statistics']['viewCount'],
        Total_videos = response['items'][i]['statistics']['videoCount'],
        playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'],
    )
    all_data.append(data)
  return all_data

# %%
allchannelstats = getStats(youtube, channel_id)

# %%
allchannelstats
# Out:
# [{'channel_name': 'Narendra Modi',
#   'Subcribers': '22900000',
#   'Views': '5144436621',
#   'Total_videos': '19644',
#   'playlist_id': 'UU1NF71EwP41VdjAU1iXdLkw'},
#  {'channel_name': 'ISRO Official',
#   'Subcribers': '4420000',
#   'Views': '162302543',
#   'Total_videos': '91',
#   'playlist_id': 'UUw5hEVOTfz_AfzsNFWyNlNg'},
#  {'channel_name': 'Apna College',
#   'Subcribers': '5170000',
#   'Views': '801456695',
#   'Total_videos': '821',
#   'playlist_id': 'UUBwmMxybNva6P_5VmxjzwqA'},
#  {'channel_name': 'CodeWithHarry',
#   'Subcribers': '5920000',
#   'Views': '748582041',
#   'Total_videos': '1537',
#   'playlist_id': 'UUeVMnSShP_Iviwkknt83cww'},
#  {'channel_name': 'Quantopian',
#   'Subcribers': '59300',
#   'Views': '3014709',
#   'Total_videos': '255',
#   'playlist_id': 'UU606MUq45P3zFLa4VGKbxsg'}]

# %%
structured_form = pd.DataFrame(allchannelstats)
structured_form
# Out:
#     channel_name Subcribers       Views Total_videos               playlist_id
# 0  Narendra Modi   22900000  5144436621        19644  UU1NF71EwP41VdjAU1iXdLkw
# 1  ISRO Official    4420000   162302543           91  UUw5hEVOTfz_AfzsNFWyNlNg
# 2   Apna College    5170000   801456695          821  UUBwmMxybNva6P_5VmxjzwqA
# 3  CodeWithHarry    5920000   748582041         1537  UUeVMnSShP_Iviwkknt83cww
# 4     Quantopian      59300     3014709          255  UU606MUq45P3zFLa4VGKbxsg
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# structured_form.groupby('channel_name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# ...

# %%
structured_form.to_csv("smadataset_youtubechannels.csv")

# %%
import pandas as pd
data = pd.read_csv("/content/smadataset_youtubechannels.csv")

# %%
data.head()
# Out:
#    Unnamed: 0   channel_name  Subcribers       Views  Total_videos  \
# 0           0   Apna College     4810000   738247545           801
# 1           1     Quantopian       56900     2899933           250
# 2           2  Narendra Modi    21900000  4854741405         23894
# 3           3  ISRO Official     4460000   161734237            90
# 4           4  CodeWithHarry     5400000   703646820          2292
#
#                 playlist_id
# 0  UUBwmMxybNva6P_5VmxjzwqA
# 1  UU606MUq45P3zFLa4VGKbxsg
# 2  UU1NF71EwP41VdjAU1iXdLkw
# 3  UUw5hEVOTfz_AfzsNFWyNlNg
# 4  UUeVMnSShP_Iviwkknt83cww
